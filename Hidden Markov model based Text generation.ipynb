# %% [markdown]
# # Hidden Markov Text generation

# %% [markdown]
# ### For this project we decided to work on the Fake news generation as a result of implementing a hidden markov model for text generation after learning from a Text corpus.
# ### Data Set found on Kaggle - India news headlines (2001 - 2018).
# ## https://www.kaggle.com/therohk/india-headlines-news-dataset
#
#
# # V1 --> implement dictionay to learn transmission and emission probabilities.

# %%
import random
import pandas as pd 
import operator

data = pd.read_csv('Data/india-news-headlines.csv')

data
# Out:
#          publish_date    headline_category  \
# 0            20010101           sports.wwe
# 1            20010102            bollywood
# 2            20010102              unknown
# 3            20010102              unknown
# 4            20010102              unknown
# 5            20010102              unknown
# 6            20010102              unknown
# 7            20010102              unknown
# 8            20010102              unknown
# 9            20010102              unknown
# 10           20010102              unknown
# 11           20010102              unknown
# 12           20010102              unknown
# 13           20010102              unknown
# 14           20010102              unknown
# 15           20010102              unknown
# 16           20010102              unknown
# 17           20010102              unknown
# 18           20010102              unknown
# 19           20010102              unknown
# 20           20010102              unknown
# 21           20010102              unknown
# 22           20010102              unknown
# 23           20010102              unknown
# 24           20010102              unknown
# 25           20010102              unknown
# 26           20010102              unknown
# 27           20010102              unknown
# 28           20010102              unknown
# 29           20010102              unknown
# ...               ...                  ...
# 2972477      20181231          world.china
# 2972478      20181231          world.china
# 2972479      20181231          world.china
# 2972480      20181231          world.china
# 2972481      20181231         world.europe
# 2972482      20181231    world.middle-east
# 2972483      20181231    world.middle-east
# 2972484      20181231    world.middle-east
# 2972485      20181231  world.rest-of-world
# 2972486      20181231  world.rest-of-world
# 2972487      20181231  world.rest-of-world
# 2972488      20181231  world.rest-of-world
# 2972489      20181231  world.rest-of-world
# 2972490      20181231  world.rest-of-world
# 2972491      20181231     world.south-asia
# 2972492      20181231     world.south-asia
# 2972493      20181231     world.south-asia
# 2972494      20181231             world.uk
# 2972495      20181231             world.us
# 2972496      20181231             world.us
# 2972497      20181231             world.us
# 2972498      20181231             world.us
# 2972499      20181231             world.us
# 2972500      20181231             world.us
# 2972501      20181231             world.us
# 2972502      20181231             world.us
# 2972503      20181231             world.us
# 2972504      20181231             world.us
# 2972505      20181231             world.us
# 2972506      20181231             world.us
#
#                                              headline_text
# 0        win over cena satisfying but defeating underta...
# 1                                              Raju Chacha
# 2        Status quo will not be disturbed at Ayodhya; s...
# 3                      Fissures in Hurriyat over Pak visit
# 4                    America's unwanted heading for India?
# 5                       For bigwigs; it is destination Goa
# 6                     Extra buses to clear tourist traffic
# 7              Dilute the power of transfers; says Riberio
# 8                        Focus shifts to teaching of Hindi
# 9                     IT will become compulsory in schools
# 10           Move to stop freedom fighters' pension flayed
# 11       Gilani claims he applied for passport 2 years ago
# 12                          Parivar dismisses PM's warning
# 13                   India; Pak exchange lists of N-plants
# 14             Will Qureshi's return really help the govt?
# 15              PM's tacit message: Put Ram tample on hold
# 16                    Text of the Prime Minister's article
# 17                  NCW to focus on violence against women
# 18                    BBC's reality TV will focus on AIIMS
# 19                           Jaitley firm on legal reforms
# 20                   Hoshangabad farmers have enough water
# 21              BJP jumps into rail track conversion issue
# 22                   America's unwanted heading for India?
# 23                 State may take AP to court over Krishna
# 24                       This official has sued the briber
# 25           Park turns temple compound as residents watch
# 26            Moves afoot to evict squatters in Urban dist
# 27                Mafia calls the shots in Gandhinagar too
# 28       Status quo will not be disturbed at Ayodhya; s...
# 29                     Fissures in Hurriyat over Pak visit
# ...                                                    ...
# 2972477  China probe readies to land on dark side of th...
# 2972478  China's Disappeared: A look at who went missin...
# 2972479  China puts into service its new lightweight ba...
# 2972480  Taiwan rebuffs China tourist snub with record ...
# 2972481  Near-blind ex-boxer puts troubled kids on righ...
# 2972482  Russian IS fighters' children return home from...
# 2972483  Young girl's tragic story makes her symbol of ...
# 2972484  Iran judiciary chief to head powerful Expedien...
# 2972485                69 migrants rescued off Malta: Navy
# 2972486  World's first plastic-free passenger flight ta...
# 2972487  Kim Jong Un expected to ring in 2019 with big ...
# 2972488           Philippine storm death toll surges to 68
# 2972489  Guatemala village mourns 2nd child to die in U...
# 2972490  DR Congo awaits result after volatile presiden...
# 2972491  Bangladesh PM Sheikh Hasina scores big electio...
# 2972492  Hasina's victory makes her the longest-serving...
# 2972493  Sheikh Hasina: Bangladesh's democracy icon-tur...
# 2972494  New life for old classics; as their copyrights...
# 2972495  Trump blames Democrats over deaths of migrant ...
# 2972496  Cyber attack disrupts printing of major newspa...
# 2972497               The curious case of vanishing vowels
# 2972498  After Mattis; Shanahan takes Pentagon helm at ...
# 2972499  Top Republican says Trump vows to 'destroy' IS...
# 2972500  Why tattoos digitally recreated on athletes' a...
# 2972501  Donald Trump's promise of a wall may not be fu...
# 2972502  For wedding guests; now a hair and glam touch-...
# 2972503  Guatemala village mourns 2nd child to die in U...
# 2972504  Veterans' support for Donald Trump strong: AP ...
# 2972505  aides give conflicting signals on donald trump...
# 2972506  Throngs to pack Times Square for mild; rainy N...
#
# [2972507 rows x 3 columns]

# %%
print(data["headline_category"].value_counts())
# Out:
# india                                                                           271030
# unknown                                                                         206571
# city.mumbai                                                                     123124
# city.delhi                                                                      112705
# business.india-business                                                         107555
# city.chandigarh                                                                  99710
# city.hyderabad                                                                   86229
# city.bengaluru                                                                   84475
# entertainment.hindi.bollywood.news                                               80586
# city.lucknow                                                                     77885
# city.ahmedabad                                                                   77530
# city.pune                                                                        75892
# city.kolkata                                                                     73189
# city.nagpur                                                                      70117
# city.goa                                                                         68225
# city.chennai                                                                     63918
# city.patna                                                                       63313
# city.jaipur                                                                      45774
# sports.icc-world-cup-2015                                                        40059
# business.international-business                                                  36095
# city.gurgaon                                                                     27964
# city.bhubaneswar                                                                 27262
# tv.news.hindi                                                                    26130
# entertainment.english.hollywood.news                                             24632
# city.guwahati                                                                    23516
# city.kochi                                                                       23182
# city.ranchi                                                                      22551
# city.ludhiana                                                                    20960
# city.bhopal                                                                      20602
# city.thiruvananthapuram                                                          20506
#                                                                                  ...
# poll                                                                                 1
# life-style-landing.books.book-launches                                               1
# entertainment.english.hollywood.specials                                             1
# independence-day-2018.priyanka-chopra-nick-jonas-enagement                           1
# india.centre-not-barred-from-granting-reservation-in-promotion-for-sc                1
# cities.kolkatta                                                                      1
# trade-war                                                                            1
# lavasa                                                                               1
# india.mp-raj-chhattisgarh-to-move-sc-against-sc                                      1
# pm-modis-us-visit                                                                    1
# are-you-experienced                                                                  1
# delhi-mass-suicide                                                                   1
# india.congress-seeks-review-of-sc-verdict-related-to-sc                              1
# sports.more-sports.others.bobsleigh                                                  1
# citizen-reporter.stories.uber                                                        1
# cji-impeachment                                                                      1
# cochin                                                                               1
# entertainment.telugu.movies.news.sumanth-ashwins-fashion-designer-s                  1
# anurag.india                                                                         1
# entertainment.hindi.bollywood.specials.dia-mirza-sahil-sanghas-dream-wedding         1
# gaming.how-to-report-a-player-hacker                                                 1
# tv.specials.english.know-everything-about-the-kardashians                            1
# brandwire.media-entertainment.tv-radio-ooh                                           1
# katie-price.biography                                                                1
# entertainment.telugu.movies.news.tollywood-directors-heap-praises-on-c               1
# global                                                                               1
# arbaaz-khan-ipl-betting-case                                                         1
# entertainment.hindi.bollywood.news.shubh-mangal-saavdhan-gets-u                      1
# india.wont-allow-dilution-of-sc                                                      1
# pantaloons-femina-miss-india-10.more-about-pfmi                                      1
# Name: headline_category, Length: 1953, dtype: int64

# %% [markdown]
# ## Future Work :
# ### -- use combinations of the tags of the headlines to establish geo - fence.
# ### -- define pseudo-catagories to generate more targeted news

# %%
sample = data["headline_text"][:]
sample
# Out:
# 0          win over cena satisfying but defeating underta...
# 1                                                Raju Chacha
# 2          Status quo will not be disturbed at Ayodhya; s...
# 3                        Fissures in Hurriyat over Pak visit
# 4                      America's unwanted heading for India?
# 5                         For bigwigs; it is destination Goa
# 6                       Extra buses to clear tourist traffic
# 7                Dilute the power of transfers; says Riberio
# 8                          Focus shifts to teaching of Hindi
# 9                       IT will become compulsory in schools
# 10             Move to stop freedom fighters' pension flayed
# 11         Gilani claims he applied for passport 2 years ago
# 12                            Parivar dismisses PM's warning
# 13                     India; Pak exchange lists of N-plants
# 14               Will Qureshi's return really help the govt?
# 15                PM's tacit message: Put Ram tample on hold
# 16                      Text of the Prime Minister's article
# 17                    NCW to focus on violence against women
# 18                      BBC's reality TV will focus on AIIMS
# 19                             Jaitley firm on legal reforms
# 20                     Hoshangabad farmers have enough water
# 21                BJP jumps into rail track conversion issue
# 22                     America's unwanted heading for India?
# 23                   State may take AP to court over Krishna
# 24                         This official has sued the briber
# 25             Park turns temple compound as residents watch
# 26              Moves afoot to evict squatters in Urban dist
# 27                  Mafia calls the shots in Gandhinagar too
# 28         Status quo will not be disturbed at Ayodhya; s...
# 29                       Fissures in Hurriyat over Pak visit
#                                  ...
# 2972477    China probe readies to land on dark side of th...
# 2972478    China's Disappeared: A look at who went missin...
# 2972479    China puts into service its new lightweight ba...
# 2972480    Taiwan rebuffs China tourist snub with record ...
# 2972481    Near-blind ex-boxer puts troubled kids on righ...
# 2972482    Russian IS fighters' children return home from...
# 2972483    Young girl's tragic story makes her symbol of ...
# 2972484    Iran judiciary chief to head powerful Expedien...
# 2972485                  69 migrants rescued off Malta: Navy
# 2972486    World's first plastic-free passenger flight ta...
# 2972487    Kim Jong Un expected to ring in 2019 with big ...
# 2972488             Philippine storm death toll surges to 68
# 2972489    Guatemala village mourns 2nd child to die in U...
# 2972490    DR Congo awaits result after volatile presiden...
# 2972491    Bangladesh PM Sheikh Hasina scores big electio...
# 2972492    Hasina's victory makes her the longest-serving...
# 2972493    Sheikh Hasina: Bangladesh's democracy icon-tur...
# 2972494    New life for old classics; as their copyrights...
# 2972495    Trump blames Democrats over deaths of migrant ...
# 2972496    Cyber attack disrupts printing of major newspa...
# 2972497                 The curious case of vanishing vowels
# 2972498    After Mattis; Shanahan takes Pentagon helm at ...
# 2972499    Top Republican says Trump vows to 'destroy' IS...
# 2972500    Why tattoos digitally recreated on athletes' a...
# 2972501    Donald Trump's promise of a wall may not be fu...
# 2972502    For wedding guests; now a hair and glam touch-...
# 2972503    Guatemala village mourns 2nd child to die in U...
# 2972504    Veterans' support for Donald Trump strong: AP ...
# 2972505    aides give conflicting signals on donald trump...
# 2972506    Throngs to pack Times Square for mild; rainy N...
# Name: headline_text, Length: 2972507, dtype: object

# %% [markdown]
# ## Major components of Hidden Markov model (v1) :
#
# 1. Observations --> The raw data headline string words --> Predicted or from original dataset.
#
# 2. Word correlations --> Emission probabilitis --> "markov_brain" defined below --> dictionary storing the transition probabilitis of every unique word after every unique word. Used a dictionary to avoid use of a sparse matrix.
#
# 3. Dynamic termination control --> The model stops when it encounters a "~END~" word being predicted next.
#     This works since the same string was added to the end of every string before training. So every likely termination term should be have the tag after it with a high probablity.

# %%
markov_brain = {}
starter_words = {}
#ender_words = []
DBN_depth = 2
## TODO: use to make the model have a longer temporal state memory
## i.e. : Implement N-grams

for headline in sample:
    headline = headline + " ~END~"
    words = headline.split()
    if len(words) < DBN_depth:
        continue
        
#     for i in range(0,DBN_depth):
#         starter_words .append(words[i])

    if words[0] in starter_words:
        starter_words[words[0]] = starter_words[words[0]] + 1
        
    else:
        starter_words[words[0]] = 1
        
    #ender_words.append(words[len(words)-1])
    
    for word in range(1,len(words)-1): # words: 
        if words[word] in markov_brain:
            if words[word+1] in markov_brain[words[word]]:
                markov_brain[words[word]][words[word+1]] = markov_brain[words[word]][words[word+1]] + 1
            else:
                markov_brain[words[word]][words[word+1]] = 1
                
            # total counter to use for probablity distrubutions
            markov_brain[words[word]]["~Total~"] = markov_brain[words[word]]["~Total~"] + 1
            
        else:
            markov_brain[words[word]] = {}
            markov_brain[words[word]][words[word+1]] = 1
            markov_brain[words[word]]["~Total~"] = 1

markov_brain

# %% [markdown]
# #### Markov_brain :
#
# {'over': {'cena': 1, <br>
#   '~Total~': 62468,<br>
#   'Pak': 50,<br>
#   'Krishna': 14,<br>
#   "ministers'": 5,<br>
#   'team': 9,<br>
#   'Coke': 3,<br>
#   'Nepal;': 2,<br>
#   'JD': 1,<br>
#   'affair': 85,<br>
#   'installing': 5,<br>
#   'airline': 3,<br>
#   '15;000': 10,<br>
#   'yet': 39,<br>

# %%
def guessNext(Observation):
    if Observation not in markov_brain:
        if random.uniform(0, 1) < 0.5 :
            posterior = random.choice(list(starter_words.keys()))
        else :
            posterior = random.choice(list(markov_brain.keys()))
    else:
        # TODO : A bunch more stochastic reasoning and selection.
        evidence = markov_brain[Observation]
        sorted_x = sorted(evidence.items(), key=lambda kv: kv[1])
        sorted_x.reverse()
        # Fix for words that are absoloutely always precedeed or followed by something specific
        if sorted_x[1][1] / evidence["~Total~"] > 0.9 :
            posterior = sorted_x[1][0]
        else:
            # Naive selection - kind of stochastic
            if len(sorted_x) > 4:
                sorted_x = sorted_x[1:int(len(sorted_x)/2)]
            posterior = random.choice(list(sorted_x))
            posterior = posterior[0]
        if posterior == "~Total~":
            posterior = guessNext(Observation)
    return posterior

# %%
curr_word = random.choice(list(starter_words.keys()))

str = ""
str = curr_word

while curr_word != "~END~":
    n_word = guessNext(curr_word)
    str = str + " " + n_word
    curr_word = n_word

str = str[:len(str)-6] + (".")

str
# Out:
# 'Computer-generated signaling business plots against Manmohan.'

# %% [markdown]
# ## /\ Here is one of the headlines that was generated by this method /\

# %% [markdown]
# ## V2 components :
# 1. Hidden states --> The node where you are in a positiobn in a sentence where the previous components have been analized into their semantic component groups. i.e. you know that you have identified Comp1--Comp2--Comp1--Comp3-- and are trying to guess at the "CompX" type of the next word. Where you also know that certain combinations of these CompX-- loops makes a complete sentence.
# 2. States --> the "CompX"s used above. Which could almost be pseudo replicas of the real gramatical part's of speech - "It Depends" heavily on the data set used for training.
# 3. Observation --> Words of the headline string
# 4. Transition Probabilities --> The probabilities of moving across CompX's temporally as we move from left to right on a sentence in its semantic component group form -->Comp1--Comp2--Comp1--Comp3--
# 5. Emission probabilities --> Comp1 has a bunch of words stored in it, and can be replaced with a value stocastically from the distribution of words belinging to that component group (figure of speech - noun, veeb, etc.)

# %% [markdown]
# ## Sources :
#
# 1. http://miha.filej.net/diploma-thesis/
# 2. https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
# 3. https://medium.com/@kangeugine/hidden-markov-model-7681c22f5b9
# 4. https://stackoverflow.com/questions/4859292/how-to-get-a-random-value-in-python-dictionary
# 5. https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
# 6. https://en.wikipedia.org/wiki/N-gram
# 7. https://web.stanford.edu/~jurafsky/slp3/3.pdf
# 8. https://medium.com/@kangeugine/hidden-markov-model-7681c22f5b9
